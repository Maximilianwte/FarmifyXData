# %%
import googlemaps
from datetime import datetime

# %%
gmaps = googlemaps.Client(key='AIzaSyDRONlJD5c6oTaAR7ja7ea2LwfficV5BKA')

# %%
geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')

# %%
geocode_result
# Out:
# [{'address_components': [{'long_name': '1600',
#     'short_name': '1600',
#     'types': ['street_number']},
#    {'long_name': 'Amphitheatre Parkway',
#     'short_name': 'Amphitheatre Pkwy',
#     'types': ['route']},
#    {'long_name': 'Mountain View',
#     'short_name': 'Mountain View',
#     'types': ['locality', 'political']},
#    {'long_name': 'Santa Clara County',
#     'short_name': 'Santa Clara County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'California',
#     'short_name': 'CA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '94043', 'short_name': '94043', 'types': ['postal_code']}],
#   'formatted_address': '1600 Amphitheatre Pkwy, Mountain View, CA 94043, USA',
#   'geometry': {'location': {'lat': 37.42230960000001, 'lng': -122.0846244},
#    'location_type': 'ROOFTOP',
# ...

# %%
places = gmaps.places_nearby(type="farm", location="-29.6960891,121.0722723", keyword="Farm", rank_by="distance")

# %%
places
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': -29.6937958,
#      'lng': 121.0287551},
#     'viewport': {'northeast': {'lat': -29.69244542010728,
#       'lng': 121.0301795798927},
#      'southwest': {'lat': -29.69514507989272, 'lng': 121.0274799201073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '70e005ba8ae3fe99e2f7dfc546e2bbd80250629f',
#    'name': 'Menzies Visitor Centre',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2592,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106228517682443243842">TJ HENNESSY</a>'],
#      'photo_reference': 'CmRaAAAAiBSHEHzlqsYpB5IPSaNF6BTzNtqkR4RCbRJpNrsb1Yi0gaH0iqybb3o4U5BkEshI9h_ADcsx0CXa1mJHOsbyzwU--0VgWcpLYP80za45r9rA_MxCP3VAmxLvn09N2lpzEhBV-xDmMbaXu_eIKHZb1mBoGhQuTExQcIRpwljLy55ZBjs6tqMuHA',
#      'width': 4608}],
#    'place_id': 'ChIJDQpdzLVRsisRwC_Wao1f66o',
# ...

# %%
places = gmaps.find_place(input="Farm Perth", input_type="textquery", fields=fieldsLST, location_bias="rectangle:-44.045852, 109.149278|-11.805441, 157.505606")

# %%
fieldsSTR = "formatted_address,geometry,name,place_id,types,business_status"
fieldsLST = ["formatted_address", "geometry", "place_id", "types"]

# %%
places = gmaps.places(query="Farm", location="-30.903989, 120.810676", type="Farm", radius=50000)

# %%
places
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIQEAAPkEHgOHV3OafgRF91MnG-HCrZQU99-7cUJUdTVLLz1sn-td6-XYy2atUY7axj_EnTI-vRPJaQbgoKU_Gmm2-t3_KWKv63UpvTnvDuo-S-gBOSF2fWLIvIybErhEIwAnjEVeSbIFf9XSH52V4b1US525qlgluhwFb6_onpFEt_53f1KGPOP5Z4SHpiZdQSZ27eV9_nHsnifDYAI_y2b1_IiVk2u22HeEMeO2prJ5Cvc3Mg8nFFze13X3kCHlN1S0W7d7wqZ1X6KKEF3QUlDJhbKjA6naHs18dKT82LFFg5ZmSFkNDQOvz94NTc6dTIY_0YqmJxSMB_S-2YvUyGRQ9CDS0py_ofIcJFaAkYwAYqgVqBjhqmai0jZBm2B_OjgSE_t7T4QzW9tQVRedqvgw3qgSEBuf1UKJGZGr2_pQ4JfxT5waFLTV-tujbtffYycxDLOXaYI9w74b',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'LOT 23 Koolyanobbing Road, Southern Cross WA 6426, Australia',
#    'geometry': {'location': {'lat': -31.195393, 'lng': 119.353092},
#     'viewport': {'northeast': {'lat': -31.19404482010728, 'lng': 119.35531395},
#      'southwest': {'lat': -31.19674447989273, 'lng': 119.34642615}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
# ...

# %%
for i in range(0, len(places["results"])):
    print(places["results"][i]["name"])
# Out:
# Pollard Farming Pty Ltd
# STIHL
# IGA X-press
# Blackwoods Kalgoorlie
# CBC Kalgoorlie
# BWS Kalgoorlie
# Truckline Truck & Trailer Parts
# ATOM
# Ausco Modular
# Toll West
# Elders Insurance Kalgoorlie
# The Prospectors patch
# Go Vita
# Kalgoorlie Case & Drill Pty Ltd
# Burra Rock Nature Reserve
# Goldfields Toyota
# ECF Farm Berlin
# NMP Farm Investment GmbH
# Farmco - Citus 12. AG
# KTG International Farming AG
